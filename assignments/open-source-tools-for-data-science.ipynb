# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Ziheng Zhang**
# Machine Learning Expert

# %% [markdown]
# *I am interested in data science because I chose Machine Learning as my postgraduate programme, and I did learn a lot about ML. I would like to further my study in data science to make use of my ML experience and make a differnece to the world.*

# %% [markdown]
# ### Cell 5 should output 15, which is the sum of variable a (10) and variable b (5).

# %%
a, b = 10, 5
print(a+b)
# Out:
# 15

# %% [markdown]
# > This is usually the reference in Markdown documents
#
# * bulleted list
# * bulleted list
# * bulleted list
#
#
# 1. numbered list no 1
# 2. numbered list no 2
# 3. numbered list no 3
